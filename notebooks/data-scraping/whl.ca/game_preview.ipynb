# %%
write_mode = 'replace'
target_table = 'whl_game_preview'

# %%
import pandas as pd
import numpy as np
import sys
sys.path.append('../../../')

import settings as st

# %%
sys.path.append('../../../production/data-scraping/utilities')

import web_utilities as wu
import database_utilities as du
import encoder_utilities as eu
import pd_utilities as pu

# %%
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
db_host = st.database['local']['host']
db_port = st.database['local']['port']
db_user = st.database['local']['user']
db_pass = st.database['local']['pass']
db_sys = st.database['local']['system']
db_db = st.database['local']['db']

# %%
key = "41b145a848f4bd67"

# %%
season_id = None
season_id = 267

# %%
if season_id == None:
    sql = "SELECT DISTINCT id FROM whl_schedule_by_season"
else:
    sql = "SELECT DISTINCT id FROM whl_schedule_by_season where season_id = {0}".format(season_id)
res = du.query_database_to_list(db_sys, db_user, db_pass, db_host, db_port, db_db, sql)

# %%
for r in res:
    game_id = r['id']
    
    url = "http://cluster.leaguestat.com/feed/index.php?feed=gc&key={0}&client_code=whl&game_id={1}&lang_code=en&fmt=json&tab=preview".format(key, game_id)
    
    json_data = wu.return_json(url)
    
    break

# %%
json_data['GC']['Preview']['HeadToHeadRecord']
# Out:
# {'home_team': {'name': 'Saskatoon Blades',
#   'w': 0,
#   'l': 0,
#   'otl': 0,
#   'sl': 0,
#   't': 0},
#  'visiting_team': {'name': 'Moose Jaw Warriors',
#   'w': 0,
#   'l': 0,
#   'otl': 0,
#   'sl': 0,
#   't': 0}}

# %%
json_data['GC']['Preview']['home_team']
# Out:
# {'team_id': '213',
#  'name': 'Saskatoon Blades',
#  'city': 'Saskatoon',
#  'team_code': 'SAS',
#  'nickname': 'Blades',
#  'divisionName': 'East',
#  'conferenceName': 'Eastern Conference',
#  'wins': 0,
#  'losses': 0,
#  'ties': 0,
#  'points': 0,
#  'ot_wins': 0,
#  'ot_losses': 0,
#  'shootout_losses': 0,
#  'goals_for': 0,
#  'goals_against': 0,
#  'penalty_minutes': 0,
#  'past_10_wins': 0,
#  'past_10_losses': 0,
#  'past_10_ties': 0,
#  'past_10_ot_losses': 0,
#  'past_10_shootout_losses': 0,
#  'home_w': 0,
#  'home_l': 0,
#  'home_t': 0,
#  'home_sl': 0,
#  'home_otl': 0,
#  'away_w': 0,
#  'away_l': 0,
#  'away_t': 0,
#  'away_sl': 0,
#  'away_otl': 0,
#  'power_plays': 0,
#  'power_play_goals': 0,
#  'times_short_handed': 0,
#  'power_play_goals_against': 0,
#  'last_game': '3-1 L @ Prince Albert (2019-03-16) Final',
#  'gamesPlayed': 0,
#  'gp': 0,
#  'pp_away': {'power_plays': 0, 'power_player_goals': 0, 'percentage': 0},
#  'pp_home': {'power_plays': 0, 'power_player_goals': 0, 'percentage': 0},
#  'pp': {'power_plays': 0, 'power_player_goals': 0, 'percentage': 0},
#  'pk_away': {'times_short_handed': 0,
#   'power_player_goals_against': 0,
#   'percentage': 0},
#  'pk_home': {'times_short_handed': 0,
#   'power_player_goals_against': 0,
#   'percentage': 0},
#  'pk': {'times_short_handed': 0,
#   'power_player_goals_against': 0,
#   'percentage': 0},
#  'pim': {'games_played': 0,
#   'penalty_minutes': 0,
#   'bench_minutes': 0,
#   'penalties_per_game': 0},
#  'longest_player_streaks': [],
#  'lastGames': [],
#  'rookie': [],
#  'leadingScorers': [],
#  'mostPIM': [],
#  'all_w': 781,
#  'all_l': 830,
#  'all_t': 61,
#  'all_otl': 74,
#  'all_sl': 36,
#  'last10': '0-0-0',
#  'streak': '0-0-0',
#  'percentage': 0,
#  'pp_percentage': 0,
#  'pk_percentage': 0,
#  'teamPIMperGame': 0,
#  'pp_vs_opp': {'power_plays': 0,
#   'power_play_goals': 0,
#   'percentage': 0,
#   'pk_percentage_of_opp': 0},
#  'season_records': {'leading_after_1st': '0-0-0-0',
#   'leading_after_2nd': '0-0-0-0',
#   'tied_after_1st': '0-0-0-0',
#   'tied_after_2nd': '0-0-0-0',
#   'trailing_after_1st': '0-0-0-0',
#   'trailing_after_2nd': '0-0-0-0',
#   'out_shooting_opponents': '0-0-0-0',
#   'out_shot_by_opponent': '0-0-0-0',
#   'one_goal_game': '0-0-0-0',
#   'two_goal_game': '0-0-0-0',
#   'three_goal_game': '0-0-0-0',
#   'four_goal_game': '0-0-0-0',
#   'five_goal_game': '0-0-0-0',
#   'six_goal_game': '0-0-0-0',
#   'sevenplus_goal_game': '0-0-0-0'},
#  'leagueRank': 9,
#  'conferenceRank': 6,
#  'divisionRank': 3,
#  'lineup': {'goalies': [{'person_id': '7619',
#     'player_id': '27473',
#     'first_name': 'Dorrin',
#     'last_name': 'Luding',
#     'start': '0',
#     'position': '7',
#     'position_str': 'G',
#     'jersey_number': '31',
#     'status': '',
#     'rookie': '0',
#     'seconds': 0,
#     'time': None,
#     'shots_against': 0,
#     'goals_against': 0,
#     'saves': 0,
#     'goals': 0,
#     'assists': 0,
#     'pim': 0},
#    {'person_id': '7625',
#     'player_id': '27479',
#     'first_name': 'Nolan',
#     'last_name': 'Maier',
#     'start': '1',
#     'position': '7',
#     'position_str': 'G',
#     'jersey_number': '73',
#     'status': '',
#     'rookie': '0',
#     'seconds': 3805,
#     'time': '63:25',
#     'shots_against': 23,
#     'goals_against': 2,
#     'saves': 21,
#     'goals': 0,
#     'assists': 0,
#     'pim': 0}],
#   'players': [{'person_id': '6605',
#     'player_id': '27388',
#     'first_name': 'Randen',
#     'last_name': 'Schmidt',
#     'start': '0',
#     'position': '3',
#     'position_str': 'LW',
#     'jersey_number': '2',
#     'status': '',
#     'rookie': '0',
#     'goals': 0,
#     'assists': 0,
#     'plusminus': 0,
#     'pim': 2,
#     'faceoff_wins': '0',
#     'faceoff_attempts': '0',
#     'hits': '0',
#     'shots': '0',
#     'shots_on': '0'},
#    {'person_id': '6076',
#     'player_id': '26901',
#     'first_name': 'Dawson',
#     'last_name': 'Davidson',
#     'start': '0',
#     'position': '1',
#     'position_str': 'D',
#     'jersey_number': '4',
#     'status': 'A',
#     'rookie': '0',
#     'goals': 0,
#     'assists': 0,
#     'plusminus': -1,
#     'pim': 0,
#     'faceoff_wins': '0',
#     'faceoff_attempts': '0',
#     'hits': '0',
#     'shots': '3',
#     'shots_on': '3'},
#    {'person_id': '8066',
#     'player_id': '27869',
#     'first_name': 'Aidan',
#     'last_name': 'De La Gorgendiere',
#     'start': '0',
#     'position': '1',
#     'position_str': 'D',
#     'jersey_number': '5',
#     'status': '',
#     'rookie': '1',
#     'goals': 0,
#     'assists': 0,
#     'plusminus': 0,
#     'pim': 0,
#     'faceoff_wins': '0',
#     'faceoff_attempts': '0',
#     'hits': '0',
#     'shots': '0',
#     'shots_on': '0'},
#    {'person_id': '6360',
#     'player_id': '27144',
#     'first_name': 'Brandon',
#     'last_name': 'Schuldhaus',
#     'start': '1',
#     'position': '1',
#     'position_str': 'D',
#     'jersey_number': '6',
#     'status': '',
#     'rookie': '0',
#     'goals': 0,
#     'assists': 2,
#     'plusminus': '+1',
#     'pim': 0,
#     'faceoff_wins': '0',
#     'faceoff_attempts': '0',
#     'hits': '0',
#     'shots': '3',
#     'shots_on': '3'},
#    {'person_id': '6406',
#     'player_id': '27190',
#     'first_name': 'Max',
#     'last_name': 'Gerlach',
#     'start': '1',
#     'position': '2',
#     'position_str': 'RW',
#     'jersey_number': '16',
#     'status': 'A',
#     'rookie': '0',
#     'goals': 1,
#     'assists': 0,
#     'plusminus': 0,
#     'pim': 0,
#     'faceoff_wins': '0',
#     'faceoff_attempts': '0',
#     'hits': '0',
#     'shots': '5',
#     'shots_on': '5'},
#    {'person_id': '7880',
#     'player_id': '27712',
#     'first_name': 'Tristen',
#     'last_name': 'Robins',
#     'start': '0',
#     'position': '4',
#     'position_str': 'C',
#     'jersey_number': '11',
#     'status': '',
#     'rookie': '1',
#     'goals': 0,
#     'assists': 1,
#     'plusminus': 0,
#     'pim': 0,
#     'faceoff_wins': '4',
#     'faceoff_attempts': '7',
#     'hits': '0',
#     'shots': '0',
#     'shots_on': '0'},
#    {'person_id': '7628',
#     'player_id': '27482',
#     'first_name': 'Gary',
#     'last_name': 'Haden',
#     'start': '1',
#     'position': '4',
#     'position_str': 'C',
#     'jersey_number': '14',
#     'status': '',
#     'rookie': '0',
#     'goals': 0,
#     'assists': 1,
#     'plusminus': 0,
#     'pim': 0,
#     'faceoff_wins': '0',
#     'faceoff_attempts': '0',
#     'hits': '0',
#     'shots': '3',
#     'shots_on': '3'},
#    {'person_id': '8049',
#     'player_id': '27852',
#     'first_name': 'Kyle',
#     'last_name': 'Crnkovic',
#     'start': '0',
#     'position': '3',
#     'position_str': 'LW',
#     'jersey_number': '16',
#     'status': '',
#     'rookie': '1',
#     'goals': 0,
#     'assists': 0,
#     'plusminus': 0,
#     'pim': 0,
#     'faceoff_wins': '0',
#     'faceoff_attempts': '0',
#     'hits': '0',
#     'shots': '1',
#     'shots_on': '1'},
#    {'person_id': '7759',
#     'player_id': '27606',
#     'first_name': 'Eric',
#     'last_name': 'Florchuk',
#     'start': '0',
#     'position': '4',
#     'position_str': 'C',
#     'jersey_number': '17',
#     'status': '',
#     'rookie': '0',
#     'goals': 0,
#     'assists': 0,
#     'plusminus': 0,
#     'pim': 0,
#     'faceoff_wins': '8',
#     'faceoff_attempts': '15',
#     'hits': '0',
#     'shots': '0',
#     'shots_on': '0'},
#    {'person_id': '7954',
#     'player_id': '27769',
#     'first_name': 'Zach',
#     'last_name': 'Huber',
#     'start': '0',
#     'position': '2',
#     'position_str': 'RW',
#     'jersey_number': '19',
#     'status': '',
#     'rookie': '0',
#     'goals': 0,
#     'assists': 0,
#     'plusminus': 0,
#     'pim': 0,
#     'faceoff_wins': '0',
#     'faceoff_attempts': '0',
#     'hits': '0',
#     'shots': '0',
#     'shots_on': '0'},
#    {'person_id': '8342',
#     'player_id': '28065',
#     'first_name': 'Emil',
#     'last_name': 'Malysjev',
#     'start': '0',
#     'position': '1',
#     'position_str': 'D',
#     'jersey_number': '23',
#     'status': '',
#     'rookie': '1',
#     'goals': 0,
#     'assists': 0,
#     'plusminus': 0,
#     'pim': 0,
#     'faceoff_wins': '0',
#     'faceoff_attempts': '0',
#     'hits': '0',
#     'shots': '3',
#     'shots_on': '3'},
#    {'person_id': '8341',
#     'player_id': '28064',
#     'first_name': 'Kristian',
#     'last_name': 'Roykas Marthinsen',
#     'start': '0',
#     'position': '3',
#     'position_str': 'LW',
#     'jersey_number': '24',
#     'status': '',
#     'rookie': '1',
#     'goals': 0,
#     'assists': 0,
#     'plusminus': 0,
#     'pim': 0,
#     'faceoff_wins': '0',
#     'faceoff_attempts': '0',
#     'hits': '0',
#     'shots': '1',
#     'shots_on': '1'},
#    {'person_id': '6077',
#     'player_id': '26902',
#     'first_name': 'Nolan',
#     'last_name': 'Kneen',
#     'start': '1',
#     'position': '1',
#     'position_str': 'D',
#     'jersey_number': '27',
#     'status': '',
#     'rookie': '0',
#     'goals': 0,
#     'assists': 1,
#     'plusminus': '+1',
#     'pim': 2,
#     'faceoff_wins': '0',
#     'faceoff_attempts': '0',
#     'hits': '0',
#     'shots': '3',
#     'shots_on': '3'},
#    {'person_id': '7692',
#     'player_id': '27539',
#     'first_name': 'Riley',
#     'last_name': 'McKay',
#     'start': '0',
#     'position': '3',
#     'position_str': 'LW',
#     'jersey_number': '39',
#     'status': '',
#     'rookie': '0',
#     'goals': 1,
#     'assists': 0,
#     'plusminus': 0,
#     'pim': 0,
#     'faceoff_wins': '0',
#     'faceoff_attempts': '0',
#     'hits': '0',
#     'shots': '5',
#     'shots_on': '5'},
#    {'person_id': '6522',
#     'player_id': '27306',
#     'first_name': 'Chase',
#     'last_name': 'Wouters',
#     'start': '1',
#     'position': '4',
#     'position_str': 'C',
#     'jersey_number': '44',
#     'status': 'C',
#     'rookie': '0',
#     'goals': 1,
#     'assists': 0,
#     'plusminus': 0,
#     'pim': 0,
#     'faceoff_wins': '18',
#     'faceoff_attempts': '25',
#     'hits': '0',
#     'shots': '5',
#     'shots_on': '5'},
#    {'person_id': '7740',
#     'player_id': '27587',
#     'first_name': 'Reece',
#     'last_name': 'Harsch',
#     'start': '0',
#     'position': '1',
#     'position_str': 'D',
#     'jersey_number': '52',
#     'status': '',
#     'rookie': '0',
#     'goals': 0,
#     'assists': 0,
#     'plusminus': -1,
#     'pim': 0,
#     'faceoff_wins': '0',
#     'faceoff_attempts': '0',
#     'hits': '0',
#     'shots': '1',
#     'shots_on': '1'},
#    {'person_id': '6396',
#     'player_id': '27180',
#     'first_name': 'Ryan',
#     'last_name': 'Hughes',
#     'start': '0',
#     'position': '4',
#     'position_str': 'C',
#     'jersey_number': '53',
#     'status': '',
#     'rookie': '0',
#     'goals': 0,
#     'assists': 0,
#     'plusminus': 0,
#     'pim': 0,
#     'faceoff_wins': '0',
#     'faceoff_attempts': '2',
#     'hits': '0',
#     'shots': '2',
#     'shots_on': '2'},
#    {'person_id': '7595',
#     'player_id': '27449',
#     'first_name': 'Kirby',
#     'last_name': 'Dach',
#     'start': '0',
#     'position': '4',
#     'position_str': 'C',
#     'jersey_number': '77',
#     'status': 'A',
#     'rookie': '0',
#     'goals': 0,
#     'assists': 1,
#     'plusminus': 0,
#     'pim': 0,
#     'faceoff_wins': '13',
#     'faceoff_attempts': '15',
#     'hits': '0',
#     'shots': '3',
#     'shots_on': '3'}]}}

# %%
json_data['GC']['Preview']['visitor_team']

# %%
json_data['GC']['Preview']['visiting_team']
